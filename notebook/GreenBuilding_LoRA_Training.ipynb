# %%
# !pip install transformers accelerate peft datasets

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/YOUR_NAME/GreenBuilding-QA-LLM.git

# %%
cd GreenBuilding-QA-LLM

# %%
python model/train_lora.py

# %%
# !zip -r lora_greenbuilding.zip lora-qlora-greenbuilding
